# %% [markdown]
# # Quantifying Shakespear
#
# In this notebook we will:
#
# 1. Read all of shakespeare's works into a list of strings
# 2. Count the frequencies of letters used
# 3. Visualize the results of the frequencies
#
# The dataset we will use is: <https://bit.ly/shakespeare-txt>

# %%
# Read the lines into a list

from io import TextIOWrapper

def read_lines(filename: str) -> list[str]:
    """Read every line from filename into a list."""
    lines: list[str] = []
    file_handle: TextIOWrapper = open(filename, "r")
    for line in file_handle:
        line = line.lower()
        line = line.strip()
        lines.append(line)
    file_handle.close()
    return lines


shakespeare_lines: list[str] = read_lines("./shakespeare.txt")
print(len(shakespeare_lines))
shakespeare_lines
# Out:
# 124455
# ['this is the 100th etext file presented by project gutenberg, and',
#  'is presented in cooperation with world library, inc., from their',
#  'library of the future and shakespeare cdroms.  project gutenberg',
#  'often releases etexts that are not placed in the public domain!!',
#  '',
#  'shakespeare',
#  '',
#  '*this etext has certain copyright implications you should read!*',
#  '',
#  '<<this electronic version of the complete works of william',
#  'shakespeare is copyright 1990-1993 by world library, inc., and is',
#  'provided by project gutenberg etext of illinois benedictine college',
#  'with permission.  electronic and machine readable copies may be',
#  'distributed so long as such copies (1) are for your or others',
#  'personal use only, and (2) are not distributed or used',
#  'commercially.  prohibited commercial distribution includes by any',
#  'service that charges for download time or for membership.>>',
#  '',
# ...

# %%
# Tally up characters

# Goal: Define a function named tally
# It will take two parameters:
# 1. A reference to a dictionary whose keys are str and values are int
# 2. A str that refers to a key in the dictionary you are tallying
# logic:
#   If the str / key is in the dictionary, increase its value by one.
#   Otherwise, set the key's value to 1 in the dictionary
#   This function returns nothing.

def tally(counts: dict[str, int], key: str) -> None:
    """Counts occurences of each key in a dict."""
    if key in counts:
        counts[key] += 1
    else:
        counts [key] = 1


def count_letters(lines: list[str]) -> dict[str, int]:
    """Count the frequencies of all letters in lines."""
    counts: dict[str, int] = {}
    for line in lines:
        for word in lines:
            for char in word:
                if char.isalpha():
                    tally(counts, char)
    # for each line in lines
    # loop through each character in the line
    #       Tally that character into counts using your tally function
    #       Challenge: Only tally a - z characters
    return counts


shakespear_letters: dict[str, int] = count_letters(shakespeare_lines)
print(shakespear_letters)
# Out:
# {'t': 41042147625, 'h': 29479406940, 'i': 31610325450, 's': 30987925995, 'e': 55656773820, 'x': 658864770, 'f': 10020618780, 'l': 21159714645, 'p': 7276137120, 'r': 29603364120, 'n': 30275172210, 'd': 18601293210, 'b': 7710733980, 'y': 11744818350, 'o': 39153543000, 'j': 594770445, 'c': 10975064175, 'g': 8487706545, 'u': 16048098885, 'a': 35986163250, 'w': 11125032450, 'm': 13870758660, 'k': 4406702640, 'v': 4675649895, 'z': 202986105, 'q': 445797810}

# %%
items_in_dict: list[tuple[str, int]] = list(shakespear_letters.items())
items_in_dict = sorted(items_in_dict)
shakespear_letters_sorted: dict[str, int] = dict(items_in_dict)
print(shakespear_letters_sorted)
# Out:
# {'achilles': 124455, 'adrian': 124455, 'aeneas': 124455, 'ajax': 124455, 'alarbus': 124455, 'amazons': 124455, 'and': 248910, 'antenor': 124455, 'apparitions': 124455, 'attendants': 622275, 'banishment': 124455, 'bardolph': 248910, 'behold': 124455, 'below': 124455, 'bianca': 124455, 'biondello': 124455, 'blackheath': 124455, 'blunt': 124455, 'boatswain': 124455, 'body': 124455, 'borne': 124455, 'breathless': 124455, 'brother': 248910, 'busines': 124455, 'caius': 124455, 'caphis': 124455, 'ceres': 124455, 'chamberlain': 124455, 'chiron': 124455, 'chorus': 124455, 'come': 124455, 'cominius': 124455, 'coventry': 124455, 'crown': 124455, 'cupid': 124455, 'curtis': 124455, 'cymbeline': 124455, 'deiphobus': 124455, 'demetrius': 124455, 'diomedes': 124455, 'doth': 124455, 'drunkards': 124455, 'england': 124455, 'ephesus': 124455, 'epilogue': 746730, 'exeunt': 6222750, 'exit': 5849385, 'flaminius': 124455, 'ford': 124455, 'francisco': 124455, 'gadshill': 124455, 'gloucestershire': 124455, '
# ...

# %%
#  Make a bar chart

from matplotlib import pyplot

pyplot.title("Frequencies of Letters")
pyplot.xlabel("Letters")
pyplot.ylabel("Frequencies")
labels: list[str] = list(shakespear_letters_sorted.keys())
values: list[int] = list(shakespear_letters_sorted.values())
pyplot.bar(labels, values)
# Out:
# <BarContainer object of 153 artists>
